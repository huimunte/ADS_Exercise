# %% [markdown]
# ## Example: Artificial Neural Network using Keras
#
# This exercise is adapted from the book Hands-on Data Science for Marketing: Chapter Customer churn and retention.
#
# Dataset is provided by IBM Watson. You can also find it here: https://www.kaggle.com/zagarsuren/telecom-churn-dataset-ibm-watson-analytics. A copy of the data is stored in this week's Data folder.
#
# Note for lecturer:
# * Link to the book via SafariBooksOnline - https://learning.oreilly.com/library/view/hands-on-data-science/9781789346343/b984726e-af92-4525-8a1f-7343a9b2ac76.xhtml
# * Sample answer in github: https://github.com/yoonhwang/hands-on-data-science-for-marketing/blob/master/ch.11/python/CustomerRetention.ipynb
#
#
# **Step 1:** first load the data into a dataframe

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# load the dataset into the dataframe df
df = pd.read_excel('./Data/WA_Fn-UseC_-Telco-Customer-Churn.xlsx')

# %% [markdown]
# **Step 2:** Show the first 10 lines of the contents in df

# %%
df.head(10).transpose()
# Out:
#                                  0             1               2  \
# customerID              7590-VHVEG    5575-GNVDE      3668-QPYBK
# gender                      Female          Male            Male
# SeniorCitizen                    0             0               0
# Partner                        Yes            No              No
# Dependents                      No            No              No
# tenure                           1            34               2
# PhoneService                    No           Yes             Yes
# MultipleLines     No phone service            No              No
# InternetService                DSL           DSL             DSL
# OnlineSecurity                  No           Yes             Yes
# OnlineBackup                   Yes            No             Yes
# DeviceProtection                No           Yes              No
# TechSupport                     No            No              No
# StreamingTV                     No            No              No
# StreamingMovies                 No            No              No
# Contract            Month-to-month      One year  Month-to-month
# PaperlessBilling               Yes            No             Yes
# PaymentMethod     Electronic check  Mailed check    Mailed check
# MonthlyCharges               29.85         56.95           53.85
# TotalCharges                 29.85        1889.5          108.15
# Churn                           No            No             Yes
#
#                                           3                 4  \
# customerID                       7795-CFOCW        9237-HQITU
# gender                                 Male            Female
# SeniorCitizen                             0                 0
# Partner                                  No                No
# Dependents                               No                No
# tenure                                   45                 2
# PhoneService                             No               Yes
# MultipleLines              No phone service                No
# InternetService                         DSL       Fiber optic
# OnlineSecurity                          Yes                No
# OnlineBackup                             No                No
# DeviceProtection                        Yes                No
# TechSupport                             Yes                No
# StreamingTV                              No                No
# StreamingMovies                          No                No
# Contract                           One year    Month-to-month
# PaperlessBilling                         No               Yes
# PaymentMethod     Bank transfer (automatic)  Electronic check
# MonthlyCharges                         42.3              70.7
# TotalCharges                        1840.75            151.65
# Churn                                    No               Yes
#
#                                  5                        6                 7  \
# customerID              9305-CDSKC               1452-KIOVK        6713-OKOMC
# gender                      Female                     Male            Female
# SeniorCitizen                    0                        0                 0
# Partner                         No                       No                No
# Dependents                      No                      Yes                No
# tenure                           8                       22                10
# PhoneService                   Yes                      Yes                No
# MultipleLines                  Yes                      Yes  No phone service
# InternetService        Fiber optic              Fiber optic               DSL
# OnlineSecurity                  No                       No               Yes
# OnlineBackup                    No                      Yes                No
# DeviceProtection               Yes                       No                No
# TechSupport                     No                       No                No
# StreamingTV                    Yes                      Yes                No
# StreamingMovies                Yes                       No                No
# Contract            Month-to-month           Month-to-month    Month-to-month
# PaperlessBilling               Yes                      Yes                No
# PaymentMethod     Electronic check  Credit card (automatic)      Mailed check
# MonthlyCharges               99.65                     89.1             29.75
# TotalCharges                 820.5                   1949.4             301.9
# Churn                          Yes                       No                No
#
#                                  8                          9
# customerID              7892-POOKP                 6388-TABGU
# gender                      Female                       Male
# SeniorCitizen                    0                          0
# Partner                        Yes                         No
# Dependents                      No                        Yes
# tenure                          28                         62
# PhoneService                   Yes                        Yes
# MultipleLines                  Yes                         No
# InternetService        Fiber optic                        DSL
# OnlineSecurity                  No                        Yes
# OnlineBackup                    No                        Yes
# DeviceProtection               Yes                         No
# TechSupport                    Yes                         No
# StreamingTV                    Yes                         No
# StreamingMovies                Yes                         No
# Contract            Month-to-month                   One year
# PaperlessBilling               Yes                         No
# PaymentMethod     Electronic check  Bank transfer (automatic)
# MonthlyCharges               104.8                      56.15
# TotalCharges               3046.05                    3487.95
# Churn                          Yes                         No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %% [markdown]
# **Q:** How many variables/attributes are there in the dataset? which is the target variable?
#
# **Step 3:** Target variable encoding: As you may have noticed from the data, the target variable, Churn, has two values: Yes and No. Please encode these values as 1 for Yes and 0 for No.

# %%
df['Churn'] = df['Churn'].apply(lambda x: 1 if x == 'Yes' else 0)

# %% [markdown]
# **Q:** What is the overall churn rate? Do you find the churn rate worth paying attention to?

# %%
df['Churn'].mean()
# Out:
# 0.2653698707936959

# %% [markdown]
# **Handling missing values in the TotalCharges column:** If you looked through the TotalCharges column in the dataset, you may have noticed that there are some records with no TotalCharges values.
#
# Since there are only 11 records with missing TotalCharges values, it is safe to simply ignore and drop those records with missing values.
#
# **Step 4:** Remove entries that have missing TotalCharges values.

# %%
df['TotalCharges'] = df['TotalCharges'].replace(' ', np.nan).astype(float)

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.dropna().shape
# Out:
# (7032, 21)

# %%
df = df.dropna()

# %% [markdown]
# **Transforming continuous variables:** The next step is to scale the continuous variables.
#
# **Step 5:** Take a look at the summary statistics for continuous variables tenure, MonthlyCharges and TotalCharges

# %%
df[['tenure', 'MonthlyCharges', 'TotalCharges']].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7032.000000     7032.000000   7032.000000
# mean     32.421786       64.798208   2283.300441
# std      24.545260       30.085974   2266.771362
# min       1.000000       18.250000     18.800000
# 25%       9.000000       35.587500    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.862500   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
df[['tenure', 'MonthlyCharges', 'TotalCharges']].head(10)
# Out:
#    tenure  MonthlyCharges  TotalCharges
# 0       1           29.85         29.85
# 1      34           56.95       1889.50
# 2       2           53.85        108.15
# 3      45           42.30       1840.75
# 4       2           70.70        151.65
# 5       8           99.65        820.50
# 6      22           89.10       1949.40
# 7      10           29.75        301.90
# 8      28          104.80       3046.05
# 9      62           56.15       3487.95

# %%
df['MonthlyCharges'] = np.log(df['MonthlyCharges'])
df['TotalCharges'] = np.log(df['TotalCharges'])

# %%
df[['tenure', 'MonthlyCharges', 'TotalCharges']].head(10)
# Out:
#    tenure  MonthlyCharges  TotalCharges
# 0       1        3.396185      3.396185
# 1      34        4.042174      7.544068
# 2       2        3.986202      4.683519
# 3      45        3.744787      7.517928
# 4       2        4.258446      5.021575
# 5       8        4.601664      6.709914
# 6      22        4.489759      7.575277
# 7      10        3.392829      5.710096
# 8      28        4.652054      8.021601
# 9      62        4.028027      8.157069

# %% [markdown]
# **Step 6:** Normalize the variables tenure, MonthlyCharges and TotalCharges so that it has a mean of 0 and standard deviation of 1 (approximately)

# %%
df['MonthlyCharges'] = np.log(df['MonthlyCharges'])
df['MonthlyCharges'] = (df['MonthlyCharges'] - df['MonthlyCharges'].mean())/df['MonthlyCharges'].std()

df['TotalCharges'] = np.log(df['TotalCharges'])
df['TotalCharges'] = (df['TotalCharges'] - df['TotalCharges'].mean())/df['TotalCharges'].std()

df['tenure'] = (df['tenure'] - df['tenure'].mean())/df['tenure'].std()

# %%
df[['tenure', 'MonthlyCharges', 'TotalCharges']].describe()
# Out:
#              tenure  MonthlyCharges  TotalCharges
# count  7.032000e+03    7.032000e+03  7.032000e+03
# mean  -1.028756e-16    4.527016e-14  8.460746e-15
# std    1.000000e+00    1.000000e+00  1.000000e+00
# min   -1.280157e+00   -1.979396e+00 -3.184383e+00
# 25%   -9.542285e-01   -6.738276e-01 -4.440479e-01
# 50%   -1.394072e-01    4.275961e-01  2.807655e-01
# 75%    9.198605e-01    7.805602e-01  7.762461e-01
# max    1.612459e+00    1.159794e+00  1.143345e+00

# %%
# test with StandardScaler, see if we can get same results
from sklearn.preprocessing import StandardScaler
df2= df.copy()

# %%
scaler = StandardScaler()
# print(scaler.fit(data))

# %%
# df2['MonthlyCharges'] = np.log(df2['MonthlyCharges'])
df2['MonthlyCharges'] = scaler.fit_transform(df2[['MonthlyCharges']])

# df2['TotalCharges'] = np.log(df2['TotalCharges'])
df2['TotalCharges'] = scaler.transform(df2[['TotalCharges']])

# df2['tenure'] = (df['tenure'] - df['tenure'].mean())/df['tenure'].std()
df2['tenure'] = scaler.fit_transform(df2[['tenure']])

# %%
df2[['tenure', 'MonthlyCharges', 'TotalCharges']].describe()
#end test
# Out:
#              tenure  MonthlyCharges  TotalCharges
# count  7.032000e+03    7.032000e+03  7.032000e+03
# mean  -6.198429e-17   -4.363846e-17 -3.684002e-14
# std    1.000071e+00    1.000071e+00  1.000071e+00
# min   -1.280248e+00   -1.979536e+00 -3.184609e+00
# 25%   -9.542963e-01   -6.738755e-01 -4.440795e-01
# 50%   -1.394171e-01    4.276265e-01  2.807854e-01
# 75%    9.199259e-01    7.806157e-01  7.763013e-01
# max    1.612573e+00    1.159876e+00  1.143426e+00

# %%
df.describe().columns
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges', 'Churn'], dtype='object')

# %%
continuous_vars = list(df.describe().columns)
continuous_vars
# Out:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges', 'Churn']

# %% [markdown]
# **One-hot encoding categorical variables:** As you can see from the data, there are many categorical variables. Let's first take a look at the number of unique values each column has. After that, use one-hot encoding technique to turn these columns into values of 0s and 1s. (Tip: read up One-hot encoding online like this: https://www.geeksforgeeks.org/ml-one-hot-encoding-of-datasets-in-python/)
#
#
# **Step 7:** Find out the number of unique values in each column.

# %%
for col in list(df.columns):
    print(col, df[col].nunique())
# Out:
# customerID 7032
# gender 2
# SeniorCitizen 2
# Partner 2
# Dependents 2
# tenure 72
# PhoneService 2
# MultipleLines 3
# InternetService 3
# OnlineSecurity 3
# OnlineBackup 3
# DeviceProtection 3
# TechSupport 3
# StreamingTV 3
# StreamingMovies 3
# Contract 3
# PaperlessBilling 2
# PaymentMethod 4
# MonthlyCharges 1584
# TotalCharges 6530
# Churn 2

# %% [markdown]
# **Q:** Which are the variables with 2 to 4 unique values? (Categorical)

# %% [markdown]
# __A: Refer Cell 16__

# %% [markdown]
# **Q:** Find out the distributions of the values stored in i) Gender ii) InternetService and iii) PaymentMethod.

# %%
df.groupby('gender').count()['customerID'].plot(
    kind='bar', color='skyblue', grid=True, figsize=(8,6), title='Gender'
)
plt.show()

df.groupby('InternetService').count()['customerID'].plot(
    kind='bar', color='skyblue', grid=True, figsize=(8,6), title='Internet Service'
)
plt.show()

df.groupby('PaymentMethod').count()['customerID'].plot(
    kind='bar', color='skyblue', grid=True, figsize=(8,6), title='Payment Method'
)
plt.show()

# %% [markdown]
# **Step 8:** Perform One-hot encoding to all columns except tenure, MonthlyCharges, TotalCharges and Churn as well as those with lower than 5 unique values in respective columns.

# %%
dummy_cols = []

sample_set = df[['tenure', 'MonthlyCharges', 'TotalCharges', 'Churn']].copy(deep=True)

for col in list(df.columns):
    if col not in ['tenure', 'MonthlyCharges', 'TotalCharges', 'Churn'] and df[col].nunique() < 5:
        dummy_vars = pd.get_dummies(df[col])
        dummy_vars.columns = [col+str(x) for x in dummy_vars.columns]        
        sample_set = pd.concat([sample_set, dummy_vars], axis=1)

# %% [markdown]
# **Step 9:** Create features and target_var consisting the correct corresponding column names from sample_set

# %%
target_var = 'Churn'
features = [x for x in list(sample_set.columns) if x != target_var]

# %%
sample_set.transpose()
# Out:
#                                             0         1         2     \
# tenure                                 -1.280157  0.064298 -1.239416
# MonthlyCharges                         -0.992189  0.106181  0.018228
# TotalCharges                           -2.623238  0.437242 -1.390788
# Churn                                   0.000000  0.000000  1.000000
# genderFemale                            1.000000  0.000000  0.000000
# genderMale                              0.000000  1.000000  1.000000
# SeniorCitizen0                          1.000000  1.000000  1.000000
# SeniorCitizen1                          0.000000  0.000000  0.000000
# PartnerNo                               0.000000  1.000000  1.000000
# PartnerYes                              1.000000  0.000000  0.000000
# DependentsNo                            1.000000  1.000000  1.000000
# DependentsYes                           0.000000  0.000000  0.000000
# PhoneServiceNo                          1.000000  0.000000  0.000000
# PhoneServiceYes                         0.000000  1.000000  1.000000
# MultipleLinesNo                         0.000000  1.000000  1.000000
# MultipleLinesNo phone service           1.000000  0.000000  0.000000
# MultipleLinesYes                        0.000000  0.000000  0.000000
# InternetServiceDSL                      1.000000  1.000000  1.000000
# InternetServiceFiber optic              0.000000  0.000000  0.000000
# InternetServiceNo                       0.000000  0.000000  0.000000
# OnlineSecurityNo                        1.000000  0.000000  0.000000
# OnlineSecurityNo internet service       0.000000  0.000000  0.000000
# OnlineSecurityYes                       0.000000  1.000000  1.000000
# OnlineBackupNo                          0.000000  1.000000  0.000000
# OnlineBackupNo internet service         0.000000  0.000000  0.000000
# OnlineBackupYes                         1.000000  0.000000  1.000000
# DeviceProtectionNo                      1.000000  0.000000  1.000000
# DeviceProtectionNo internet service     0.000000  0.000000  0.000000
# DeviceProtectionYes                     0.000000  1.000000  0.000000
# TechSupportNo                           1.000000  1.000000  1.000000
# TechSupportNo internet service          0.000000  0.000000  0.000000
# TechSupportYes                          0.000000  0.000000  0.000000
# StreamingTVNo                           1.000000  1.000000  1.000000
# StreamingTVNo internet service          0.000000  0.000000  0.000000
# StreamingTVYes                          0.000000  0.000000  0.000000
# StreamingMoviesNo                       1.000000  1.000000  1.000000
# StreamingMoviesNo internet service      0.000000  0.000000  0.000000
# StreamingMoviesYes                      0.000000  0.000000  0.000000
# ContractMonth-to-month                  1.000000  0.000000  1.000000
# ContractOne year                        0.000000  1.000000  0.000000
# ContractTwo year                        0.000000  0.000000  0.000000
# PaperlessBillingNo                      0.000000  1.000000  0.000000
# PaperlessBillingYes                     1.000000  0.000000  1.000000
# PaymentMethodBank transfer (automatic)  0.000000  0.000000  0.000000
# PaymentMethodCredit card (automatic)    0.000000  0.000000  0.000000
# PaymentMethodElectronic check           1.000000  0.000000  0.000000
# PaymentMethodMailed check               0.000000  1.000000  1.000000
#
#                                             3         4         5     \
# tenure                                  0.512450 -1.239416 -0.994970
# MonthlyCharges                         -0.375844  0.434951  0.923890
# TotalCharges                            0.423932 -1.123535 -0.012086
# Churn                                   0.000000  1.000000  1.000000
# genderFemale                            0.000000  1.000000  1.000000
# genderMale                              1.000000  0.000000  0.000000
# SeniorCitizen0                          1.000000  1.000000  1.000000
# SeniorCitizen1                          0.000000  0.000000  0.000000
# PartnerNo                               1.000000  1.000000  1.000000
# PartnerYes                              0.000000  0.000000  0.000000
# DependentsNo                            1.000000  1.000000  1.000000
# DependentsYes                           0.000000  0.000000  0.000000
# PhoneServiceNo                          1.000000  0.000000  0.000000
# PhoneServiceYes                         0.000000  1.000000  1.000000
# MultipleLinesNo                         0.000000  1.000000  0.000000
# MultipleLinesNo phone service           1.000000  0.000000  0.000000
# MultipleLinesYes                        0.000000  0.000000  1.000000
# InternetServiceDSL                      1.000000  0.000000  0.000000
# InternetServiceFiber optic              0.000000  1.000000  1.000000
# InternetServiceNo                       0.000000  0.000000  0.000000
# OnlineSecurityNo                        0.000000  1.000000  1.000000
# OnlineSecurityNo internet service       0.000000  0.000000  0.000000
# OnlineSecurityYes                       1.000000  0.000000  0.000000
# OnlineBackupNo                          1.000000  1.000000  1.000000
# OnlineBackupNo internet service         0.000000  0.000000  0.000000
# OnlineBackupYes                         0.000000  0.000000  0.000000
# DeviceProtectionNo                      0.000000  1.000000  0.000000
# DeviceProtectionNo internet service     0.000000  0.000000  0.000000
# DeviceProtectionYes                     1.000000  0.000000  1.000000
# TechSupportNo                           0.000000  1.000000  1.000000
# TechSupportNo internet service          0.000000  0.000000  0.000000
# TechSupportYes                          1.000000  0.000000  0.000000
# StreamingTVNo                           1.000000  1.000000  0.000000
# StreamingTVNo internet service          0.000000  0.000000  0.000000
# StreamingTVYes                          0.000000  0.000000  1.000000
# StreamingMoviesNo                       1.000000  1.000000  0.000000
# StreamingMoviesNo internet service      0.000000  0.000000  0.000000
# StreamingMoviesYes                      0.000000  0.000000  1.000000
# ContractMonth-to-month                  0.000000  1.000000  1.000000
# ContractOne year                        1.000000  0.000000  0.000000
# ContractTwo year                        0.000000  0.000000  0.000000
# PaperlessBillingNo                      1.000000  0.000000  0.000000
# PaperlessBillingYes                     0.000000  1.000000  1.000000
# PaymentMethodBank transfer (automatic)  1.000000  0.000000  0.000000
# PaymentMethodCredit card (automatic)    0.000000  0.000000  0.000000
# PaymentMethodElectronic check           0.000000  1.000000  1.000000
# PaymentMethodMailed check               0.000000  0.000000  0.000000
#
#                                             6         7         8     \
# tenure                                 -0.424595 -0.913487 -0.180148
# MonthlyCharges                          0.768600 -0.998424  0.992586
# TotalCharges                            0.453073 -0.630811  0.672600
# Churn                                   0.000000  0.000000  1.000000
# genderFemale                            0.000000  1.000000  1.000000
# genderMale                              1.000000  0.000000  0.000000
# SeniorCitizen0                          1.000000  1.000000  1.000000
# SeniorCitizen1                          0.000000  0.000000  0.000000
# PartnerNo                               1.000000  1.000000  0.000000
# PartnerYes                              0.000000  0.000000  1.000000
# DependentsNo                            0.000000  1.000000  1.000000
# DependentsYes                           1.000000  0.000000  0.000000
# PhoneServiceNo                          0.000000  1.000000  0.000000
# PhoneServiceYes                         1.000000  0.000000  1.000000
# MultipleLinesNo                         0.000000  0.000000  0.000000
# MultipleLinesNo phone service           0.000000  1.000000  0.000000
# MultipleLinesYes                        1.000000  0.000000  1.000000
# InternetServiceDSL                      0.000000  1.000000  0.000000
# InternetServiceFiber optic              1.000000  0.000000  1.000000
# InternetServiceNo                       0.000000  0.000000  0.000000
# OnlineSecurityNo                        1.000000  0.000000  1.000000
# OnlineSecurityNo internet service       0.000000  0.000000  0.000000
# OnlineSecurityYes                       0.000000  1.000000  0.000000
# OnlineBackupNo                          0.000000  1.000000  1.000000
# OnlineBackupNo internet service         0.000000  0.000000  0.000000
# OnlineBackupYes                         1.000000  0.000000  0.000000
# DeviceProtectionNo                      1.000000  1.000000  0.000000
# DeviceProtectionNo internet service     0.000000  0.000000  0.000000
# DeviceProtectionYes                     0.000000  0.000000  1.000000
# TechSupportNo                           1.000000  1.000000  0.000000
# TechSupportNo internet service          0.000000  0.000000  0.000000
# TechSupportYes                          0.000000  0.000000  1.000000
# StreamingTVNo                           0.000000  1.000000  0.000000
# StreamingTVNo internet service          0.000000  0.000000  0.000000
# StreamingTVYes                          1.000000  0.000000  1.000000
# StreamingMoviesNo                       1.000000  1.000000  0.000000
# StreamingMoviesNo internet service      0.000000  0.000000  0.000000
# StreamingMoviesYes                      0.000000  0.000000  1.000000
# ContractMonth-to-month                  1.000000  1.000000  1.000000
# ContractOne year                        0.000000  0.000000  0.000000
# ContractTwo year                        0.000000  0.000000  0.000000
# PaperlessBillingNo                      0.000000  1.000000  0.000000
# PaperlessBillingYes                     1.000000  0.000000  1.000000
# PaymentMethodBank transfer (automatic)  0.000000  0.000000  0.000000
# PaymentMethodCredit card (automatic)    1.000000  0.000000  0.000000
# PaymentMethodElectronic check           0.000000  0.000000  1.000000
# PaymentMethodMailed check               0.000000  1.000000  0.000000
#
#                                             9     ...      7033      7034  \
# tenure                                  1.205048  ...  0.227262  1.408753
# MonthlyCharges                          0.084066  ...  0.409543  0.968391
# TotalCharges                            0.736819  ...  0.600863  1.043954
# Churn                                   0.000000  ...  0.000000  1.000000
# genderFemale                            0.000000  ...  0.000000  1.000000
# genderMale                              1.000000  ...  1.000000  0.000000
# SeniorCitizen0                          1.000000  ...  1.000000  1.000000
# SeniorCitizen1                          0.000000  ...  0.000000  0.000000
# PartnerNo                               1.000000  ...  1.000000  1.000000
# PartnerYes                              0.000000  ...  0.000000  0.000000
# DependentsNo                            0.000000  ...  1.000000  1.000000
# DependentsYes                           1.000000  ...  0.000000  0.000000
# PhoneServiceNo                          0.000000  ...  0.000000  0.000000
# PhoneServiceYes                         1.000000  ...  1.000000  1.000000
# MultipleLinesNo                         1.000000  ...  1.000000  0.000000
# MultipleLinesNo phone service           0.000000  ...  0.000000  0.000000
# MultipleLinesYes                        0.000000  ...  0.000000  1.000000
# InternetServiceDSL                      1.000000  ...  0.000000  0.000000
# InternetServiceFiber optic              0.000000  ...  1.000000  1.000000
# InternetServiceNo                       0.000000  ...  0.000000  0.000000
# OnlineSecurityNo                        0.000000  ...  1.000000  0.000000
# OnlineSecurityNo internet service       0.000000  ...  0.000000  0.000000
# OnlineSecurityYes                       1.000000  ...  0.000000  1.000000
# OnlineBackupNo                          0.000000  ...  1.000000  0.000000
# OnlineBackupNo internet service         0.000000  ...  0.000000  0.000000
# OnlineBackupYes                         1.000000  ...  0.000000  1.000000
# DeviceProtectionNo                      1.000000  ...  1.000000  0.000000
# DeviceProtectionNo internet service     0.000000  ...  0.000000  0.000000
# DeviceProtectionYes                     0.000000  ...  0.000000  1.000000
# TechSupportNo                           1.000000  ...  1.000000  1.000000
# TechSupportNo internet service          0.000000  ...  0.000000  0.000000
# TechSupportYes                          0.000000  ...  0.000000  0.000000
# StreamingTVNo                           1.000000  ...  1.000000  0.000000
# StreamingTVNo internet service          0.000000  ...  0.000000  0.000000
# StreamingTVYes                          0.000000  ...  0.000000  1.000000
# StreamingMoviesNo                       1.000000  ...  1.000000  1.000000
# StreamingMoviesNo internet service      0.000000  ...  0.000000  0.000000
# StreamingMoviesYes                      0.000000  ...  0.000000  0.000000
# ContractMonth-to-month                  0.000000  ...  1.000000  1.000000
# ContractOne year                        1.000000  ...  0.000000  0.000000
# ContractTwo year                        0.000000  ...  0.000000  0.000000
# PaperlessBillingNo                      1.000000  ...  0.000000  0.000000
# PaperlessBillingYes                     0.000000  ...  1.000000  1.000000
# PaymentMethodBank transfer (automatic)  1.000000  ...  0.000000  0.000000
# PaymentMethodCredit card (automatic)    0.000000  ...  1.000000  1.000000
# PaymentMethodElectronic check           0.000000  ...  0.000000  0.000000
# PaymentMethodMailed check               0.000000  ...  0.000000  0.000000
#
#                                             7035      7036      7037  \
# tenure                                 -0.546818 -0.832005  1.612459
# MonthlyCharges                          0.591771  0.203650 -1.666952
# TotalCharges                            0.316353 -0.068978  0.288999
# Churn                                   0.000000  0.000000  0.000000
# genderFemale                            0.000000  1.000000  1.000000
# genderMale                              1.000000  0.000000  0.000000
# SeniorCitizen0                          1.000000  1.000000  1.000000
# SeniorCitizen1                          0.000000  0.000000  0.000000
# PartnerNo                               1.000000  1.000000  1.000000
# PartnerYes                              0.000000  0.000000  0.000000
# DependentsNo                            1.000000  1.000000  1.000000
# DependentsYes                           0.000000  0.000000  0.000000
# PhoneServiceNo                          0.000000  1.000000  0.000000
# PhoneServiceYes                         1.000000  0.000000  1.000000
# MultipleLinesNo                         1.000000  0.000000  1.000000
# MultipleLinesNo phone service           0.000000  1.000000  0.000000
# MultipleLinesYes                        0.000000  0.000000  0.000000
# InternetServiceDSL                      0.000000  1.000000  0.000000
# InternetServiceFiber optic              1.000000  0.000000  0.000000
# InternetServiceNo                       0.000000  0.000000  1.000000
# OnlineSecurityNo                        1.000000  1.000000  0.000000
# OnlineSecurityNo internet service       0.000000  0.000000  1.000000
# OnlineSecurityYes                       0.000000  0.000000  0.000000
# OnlineBackupNo                          1.000000  0.000000  0.000000
# OnlineBackupNo internet service         0.000000  0.000000  1.000000
# OnlineBackupYes                         0.000000  1.000000  0.000000
# DeviceProtectionNo                      1.000000  0.000000  0.000000
# DeviceProtectionNo internet service     0.000000  0.000000  1.000000
# DeviceProtectionYes                     0.000000  1.000000  0.000000
# TechSupportNo                           1.000000  0.000000  0.000000
# TechSupportNo internet service          0.000000  0.000000  1.000000
# TechSupportYes                          0.000000  1.000000  0.000000
# StreamingTVNo                           0.000000  0.000000  0.000000
# StreamingTVNo internet service          0.000000  0.000000  1.000000
# StreamingTVYes                          1.000000  1.000000  0.000000
# StreamingMoviesNo                       1.000000  0.000000  0.000000
# StreamingMoviesNo internet service      0.000000  0.000000  1.000000
# StreamingMoviesYes                      0.000000  1.000000  0.000000
# ContractMonth-to-month                  1.000000  0.000000  0.000000
# ContractOne year                        0.000000  1.000000  0.000000
# ContractTwo year                        0.000000  0.000000  1.000000
# PaperlessBillingNo                      0.000000  1.000000  0.000000
# PaperlessBillingYes                     1.000000  0.000000  1.000000
# PaymentMethodBank transfer (automatic)  1.000000  0.000000  1.000000
# PaymentMethodCredit card (automatic)    0.000000  0.000000  0.000000
# PaymentMethodElectronic check           0.000000  1.000000  0.000000
# PaymentMethodMailed check               0.000000  0.000000  0.000000
#
#                                             7038      7039      7040  \
# tenure                                 -0.343113  1.612459 -0.872746
# MonthlyCharges                          0.698721  0.971691 -1.007829
# TotalCharges                            0.463620  1.072886 -0.539472
# Churn                                   0.000000  0.000000  0.000000
# genderFemale                            0.000000  1.000000  1.000000
# genderMale                              1.000000  0.000000  0.000000
# SeniorCitizen0                          1.000000  1.000000  1.000000
# SeniorCitizen1                          0.000000  0.000000  0.000000
# PartnerNo                               0.000000  0.000000  0.000000
# PartnerYes                              1.000000  1.000000  1.000000
# DependentsNo                            0.000000  0.000000  0.000000
# DependentsYes                           1.000000  1.000000  1.000000
# PhoneServiceNo                          0.000000  0.000000  1.000000
# PhoneServiceYes                         1.000000  1.000000  0.000000
# MultipleLinesNo                         0.000000  0.000000  0.000000
# MultipleLinesNo phone service           0.000000  0.000000  1.000000
# MultipleLinesYes                        1.000000  1.000000  0.000000
# InternetServiceDSL                      1.000000  0.000000  1.000000
# InternetServiceFiber optic              0.000000  1.000000  0.000000
# InternetServiceNo                       0.000000  0.000000  0.000000
# OnlineSecurityNo                        0.000000  1.000000  0.000000
# OnlineSecurityNo internet service       0.000000  0.000000  0.000000
# OnlineSecurityYes                       1.000000  0.000000  1.000000
# OnlineBackupNo                          1.000000  0.000000  1.000000
# OnlineBackupNo internet service         0.000000  0.000000  0.000000
# OnlineBackupYes                         0.000000  1.000000  0.000000
# DeviceProtectionNo                      0.000000  0.000000  1.000000
# DeviceProtectionNo internet service     0.000000  0.000000  0.000000
# DeviceProtectionYes                     1.000000  1.000000  0.000000
# TechSupportNo                           0.000000  1.000000  1.000000
# TechSupportNo internet service          0.000000  0.000000  0.000000
# TechSupportYes                          1.000000  0.000000  0.000000
# StreamingTVNo                           0.000000  0.000000  1.000000
# StreamingTVNo internet service          0.000000  0.000000  0.000000
# StreamingTVYes                          1.000000  1.000000  0.000000
# StreamingMoviesNo                       0.000000  0.000000  1.000000
# StreamingMoviesNo internet service      0.000000  0.000000  0.000000
# StreamingMoviesYes                      1.000000  1.000000  0.000000
# ContractMonth-to-month                  0.000000  0.000000  1.000000
# ContractOne year                        1.000000  1.000000  0.000000
# ContractTwo year                        0.000000  0.000000  0.000000
# PaperlessBillingNo                      0.000000  0.000000  0.000000
# PaperlessBillingYes                     1.000000  1.000000  1.000000
# PaymentMethodBank transfer (automatic)  0.000000  0.000000  0.000000
# PaymentMethodCredit card (automatic)    0.000000  1.000000  0.000000
# PaymentMethodElectronic check           0.000000  0.000000  1.000000
# PaymentMethodMailed check               1.000000  0.000000  0.000000
#
#                                             7041      7042
# tenure                                 -1.157934  1.368012
# MonthlyCharges                          0.510061  1.003530
# TotalCharges                           -0.620450  1.041315
# Churn                                   1.000000  0.000000
# genderFemale                            0.000000  0.000000
# genderMale                              1.000000  1.000000
# SeniorCitizen0                          0.000000  1.000000
# SeniorCitizen1                          1.000000  0.000000
# PartnerNo                               0.000000  1.000000
# PartnerYes                              1.000000  0.000000
# DependentsNo                            1.000000  1.000000
# DependentsYes                           0.000000  0.000000
# PhoneServiceNo                          0.000000  0.000000
# PhoneServiceYes                         1.000000  1.000000
# MultipleLinesNo                         0.000000  1.000000
# MultipleLinesNo phone service           0.000000  0.000000
# MultipleLinesYes                        1.000000  0.000000
# InternetServiceDSL                      0.000000  0.000000
# InternetServiceFiber optic              1.000000  1.000000
# InternetServiceNo                       0.000000  0.000000
# OnlineSecurityNo                        1.000000  0.000000
# OnlineSecurityNo internet service       0.000000  0.000000
# OnlineSecurityYes                       0.000000  1.000000
# OnlineBackupNo                          1.000000  1.000000
# OnlineBackupNo internet service         0.000000  0.000000
# OnlineBackupYes                         0.000000  0.000000
# DeviceProtectionNo                      1.000000  0.000000
# DeviceProtectionNo internet service     0.000000  0.000000
# DeviceProtectionYes                     0.000000  1.000000
# TechSupportNo                           1.000000  0.000000
# TechSupportNo internet service          0.000000  0.000000
# TechSupportYes                          0.000000  1.000000
# StreamingTVNo                           1.000000  0.000000
# StreamingTVNo internet service          0.000000  0.000000
# StreamingTVYes                          0.000000  1.000000
# StreamingMoviesNo                       1.000000  0.000000
# StreamingMoviesNo internet service      0.000000  0.000000
# StreamingMoviesYes                      0.000000  1.000000
# ContractMonth-to-month                  1.000000  0.000000
# ContractOne year                        0.000000  0.000000
# ContractTwo year                        0.000000  1.000000
# PaperlessBillingNo                      0.000000  0.000000
# PaperlessBillingYes                     1.000000  1.000000
# PaymentMethodBank transfer (automatic)  0.000000  1.000000
# PaymentMethodCredit card (automatic)    0.000000  0.000000
# PaymentMethodElectronic check           0.000000  0.000000
# PaymentMethodMailed check               1.000000  0.000000
#
# [47 rows x 7032 columns]

# %% [markdown]
# ## ANN with Keras
# For building ANN models in Python, we are going to use keras package, which is a high-level neural networks library. For more details, we recommend you visit their official documentation at the following link: https://keras.io/. Before we can use this package for building ANN models, we need to install two packages: tensorflow and keras. The keras package uses tensorflow as a backend for building neural network models, so we need to install tensorflow first. You can install these two packages using the following pip commands in your Terminal:
#
#     pip install tensorflow
#     pip install keras
#
# if you wish to use conda to install, then use the following command:
#
#     conda install keras
#
# **Step 10:** Build a neural network model with one hidden layer using keras. Import Sequential from keras.model and Dense from keras.layers. Create a model using the Sequential model. Use the following parameters:
#
# * select relu as activation function for the input layer (set output units = 16)
# * select relu as activation function for the hidden layer (set output units = 8)
# * select sigmoid as activation function for the ouput layer (set output units = 1)

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(16, input_dim=len(features), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# **Step 11:** The final step to build a neural network model with the keras package is to compile this model. Use the adam optimizer. Select binary_crossentropy as the loss function, and the accuracy metric to evaluate the model performance during training.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# **Step 12:** Split the dataset to training and testing sample sets. Set 70% for training and 30% for testing.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    sample_set[features], 
    sample_set[target_var], 
    test_size=0.3
)

# %% [markdown]
# **Step 13:** Train the neural network model using epochs = 50, and batch size of 100

# %%
model.fit(X_train, y_train, epochs=150, batch_size=100)
# Out:
# Epoch 1/150
# 50/50 [==============================] - 1s 2ms/step - loss: 0.8371 - accuracy: 0.3046
# Epoch 2/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6490 - accuracy: 0.6688
# Epoch 3/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5402 - accuracy: 0.7452
# Epoch 4/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4500 - accuracy: 0.7946
# Epoch 5/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4215 - accuracy: 0.8035
# Epoch 6/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4137 - accuracy: 0.8062
# Epoch 7/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4093 - accuracy: 0.8068
# Epoch 8/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4073 - accuracy: 0.8076
# Epoch 9/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4058 - accuracy: 0.8066
# Epoch 10/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.4048 - accuracy: 0.8058
# Epoch 11/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4042 - accuracy: 0.8070
# Epoch 12/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4035 - accuracy: 0.8054
# Epoch 13/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4026 - accuracy: 0.8086
# Epoch 14/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4023 - accuracy: 0.8072
# Epoch 15/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4013 - accuracy: 0.8074
# Epoch 16/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4001 - accuracy: 0.8094
# Epoch 17/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4003 - accuracy: 0.8056
# Epoch 18/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3999 - accuracy: 0.8072
# Epoch 19/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3993 - accuracy: 0.8076
# Epoch 20/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3989 - accuracy: 0.8094
# Epoch 21/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3986 - accuracy: 0.8080
# Epoch 22/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3987 - accuracy: 0.8098
# Epoch 23/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3974 - accuracy: 0.8056
# Epoch 24/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3970 - accuracy: 0.8064
# Epoch 25/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3966 - accuracy: 0.8078
# Epoch 26/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3966 - accuracy: 0.8086
# Epoch 27/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3958 - accuracy: 0.8108
# Epoch 28/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3956 - accuracy: 0.8088
# Epoch 29/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3957 - accuracy: 0.8098
# Epoch 30/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3949 - accuracy: 0.8100
# Epoch 31/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3947 - accuracy: 0.8092
# Epoch 32/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.8066
# Epoch 33/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3945 - accuracy: 0.8096
# Epoch 34/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3954 - accuracy: 0.8098
# Epoch 35/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3932 - accuracy: 0.8084
# Epoch 36/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3934 - accuracy: 0.8102
# Epoch 37/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3925 - accuracy: 0.8096
# Epoch 38/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3921 - accuracy: 0.8119
# Epoch 39/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3938 - accuracy: 0.8108
# Epoch 40/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3925 - accuracy: 0.8108
# Epoch 41/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3916 - accuracy: 0.8092
# Epoch 42/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3913 - accuracy: 0.8104
# Epoch 43/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3914 - accuracy: 0.8115
# Epoch 44/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3909 - accuracy: 0.8111
# Epoch 45/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3908 - accuracy: 0.8131
# Epoch 46/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3910 - accuracy: 0.8123
# Epoch 47/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3903 - accuracy: 0.8135
# Epoch 48/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3902 - accuracy: 0.8145
# Epoch 49/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3901 - accuracy: 0.8119
# Epoch 50/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3903 - accuracy: 0.8113
# Epoch 51/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3903 - accuracy: 0.8117
# Epoch 52/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3892 - accuracy: 0.8139
# Epoch 53/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3892 - accuracy: 0.8165
# Epoch 54/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3896 - accuracy: 0.8115
# Epoch 55/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3881 - accuracy: 0.8143
# Epoch 56/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3888 - accuracy: 0.8137
# Epoch 57/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3888 - accuracy: 0.8143
# Epoch 58/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3879 - accuracy: 0.8153
# Epoch 59/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3880 - accuracy: 0.8147
# Epoch 60/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3874 - accuracy: 0.8133
# Epoch 61/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3881 - accuracy: 0.8157
# Epoch 62/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3873 - accuracy: 0.8135
# Epoch 63/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3869 - accuracy: 0.8125
# Epoch 64/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3868 - accuracy: 0.8117
# Epoch 65/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3866 - accuracy: 0.8141
# Epoch 66/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3874 - accuracy: 0.8143
# Epoch 67/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3862 - accuracy: 0.8153
# Epoch 68/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3855 - accuracy: 0.8165
# Epoch 69/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3858 - accuracy: 0.8139
# Epoch 70/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3853 - accuracy: 0.8188
# Epoch 71/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3873 - accuracy: 0.8113
# Epoch 72/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3853 - accuracy: 0.8163
# Epoch 73/150
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3845 - accuracy: 0.8151
# Epoch 74/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3839 - accuracy: 0.8165
# Epoch 75/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3843 - accuracy: 0.8171
# Epoch 76/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3847 - accuracy: 0.8161
# Epoch 77/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3839 - accuracy: 0.8171
# Epoch 78/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3835 - accuracy: 0.8149
# Epoch 79/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3832 - accuracy: 0.8143
# Epoch 80/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3843 - accuracy: 0.8176
# Epoch 81/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3837 - accuracy: 0.8182
# Epoch 82/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3828 - accuracy: 0.8163
# Epoch 83/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3825 - accuracy: 0.8167
# Epoch 84/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3821 - accuracy: 0.8180
# Epoch 85/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3820 - accuracy: 0.8159
# Epoch 86/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3830 - accuracy: 0.8184
# Epoch 87/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3815 - accuracy: 0.8161
# Epoch 88/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3815 - accuracy: 0.8186
# Epoch 89/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3812 - accuracy: 0.8174
# Epoch 90/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3810 - accuracy: 0.8174
# Epoch 91/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3806 - accuracy: 0.8186
# Epoch 92/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3812 - accuracy: 0.8202
# Epoch 93/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3803 - accuracy: 0.8182
# Epoch 94/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3806 - accuracy: 0.8180
# Epoch 95/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3802 - accuracy: 0.8200
# Epoch 96/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3807 - accuracy: 0.8216
# Epoch 97/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3802 - accuracy: 0.8198
# Epoch 98/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3805 - accuracy: 0.8180
# Epoch 99/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3796 - accuracy: 0.8182
# Epoch 100/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3796 - accuracy: 0.8171
# Epoch 101/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3793 - accuracy: 0.8194
# Epoch 102/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3801 - accuracy: 0.8200
# Epoch 103/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3793 - accuracy: 0.8192
# Epoch 104/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3793 - accuracy: 0.8184
# Epoch 105/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3789 - accuracy: 0.8171
# Epoch 106/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3794 - accuracy: 0.8184
# Epoch 107/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3784 - accuracy: 0.8180
# Epoch 108/150
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3789 - accuracy: 0.8190
# Epoch 109/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3786 - accuracy: 0.8176
# Epoch 110/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3787 - accuracy: 0.8188
# Epoch 111/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3779 - accuracy: 0.8192
# Epoch 112/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3777 - accuracy: 0.8206
# Epoch 113/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3775 - accuracy: 0.8214
# Epoch 114/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3787 - accuracy: 0.8178
# Epoch 115/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3769 - accuracy: 0.8192
# Epoch 116/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3773 - accuracy: 0.8196
# Epoch 117/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3775 - accuracy: 0.8163
# Epoch 118/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3764 - accuracy: 0.8222
# Epoch 119/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3768 - accuracy: 0.8200
# Epoch 120/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3761 - accuracy: 0.8210
# Epoch 121/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3757 - accuracy: 0.8236
# Epoch 122/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3761 - accuracy: 0.8198
# Epoch 123/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3755 - accuracy: 0.8226
# Epoch 124/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3755 - accuracy: 0.8210
# Epoch 125/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3760 - accuracy: 0.8204
# Epoch 126/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3758 - accuracy: 0.8216
# Epoch 127/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3751 - accuracy: 0.8214
# Epoch 128/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3749 - accuracy: 0.8232
# Epoch 129/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3754 - accuracy: 0.8180
# Epoch 130/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3751 - accuracy: 0.8214
# Epoch 131/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3743 - accuracy: 0.8220
# Epoch 132/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3758 - accuracy: 0.8208
# Epoch 133/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3739 - accuracy: 0.8230
# Epoch 134/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3738 - accuracy: 0.8192
# Epoch 135/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3742 - accuracy: 0.8210
# Epoch 136/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3737 - accuracy: 0.8202
# Epoch 137/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3730 - accuracy: 0.8212
# Epoch 138/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3735 - accuracy: 0.8196
# Epoch 139/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3729 - accuracy: 0.8222
# Epoch 140/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3725 - accuracy: 0.8210
# Epoch 141/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3725 - accuracy: 0.8212
# Epoch 142/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3732 - accuracy: 0.8253
# Epoch 143/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3720 - accuracy: 0.8230
# Epoch 144/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3714 - accuracy: 0.8224
# Epoch 145/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3733 - accuracy: 0.8226
# Epoch 146/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3715 - accuracy: 0.8222
# Epoch 147/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3715 - accuracy: 0.8228
# Epoch 148/150
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3717 - accuracy: 0.8222
# Epoch 149/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3725 - accuracy: 0.8204
# Epoch 150/150
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3725 - accuracy: 0.8178

# %% [markdown]
# *Note:* As you can see from this output, loss typically decreases and the accuracy (acc) improves in each epoch. However, the rate of model performance improvement decreases over time. As you can see from this output, there are big improvements in the loss and accuracy measures in the first few epochs and the amount of performance gain decreases over time. You can monitor this process and decide to stop when the amount of performance gain is minimal.

# %% [markdown]
# ## Model evaluations
# Now that we have built our first neural network model, let's evaluate its performance. We are going to look at the overall accuracy, precision, and recall, as well as the receiver operating characteristic (ROC) curve and area under the curve (AUC). First, execute the following code:

# %%
y_test
# Out:
# 2480    1
# 1079    0
# 3823    0
# 1493    0
# 2245    0
#        ..
# 5298    0
# 395     0
# 4662    0
# 4300    0
# 2972    0
# Name: Churn, Length: 2110, dtype: int64

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
in_sample_preds = [round(x[0]) for x in model.predict(X_train)]
out_sample_preds = [round(x[0]) for x in model.predict(X_test)]

# %% [markdown]
# **Step 14:** Print the following information: Accuracy, precision and recall for the above predictions.

# %%
print('In-Sample Accuracy: %0.4f' % accuracy_score(y_train, in_sample_preds))
print('Out-of-Sample Accuracy: %0.4f' % accuracy_score(y_test, out_sample_preds))

print('\n')

print('In-Sample Precision: %0.4f' % precision_score(y_train, in_sample_preds))
print('Out-of-Sample Precision: %0.4f' % precision_score(y_test, out_sample_preds))

print('\n')

print('In-Sample Recall: %0.4f' % recall_score(y_train, in_sample_preds))
print('Out-of-Sample Recall: %0.4f' % recall_score(y_test, out_sample_preds))
# Out:
# In-Sample Accuracy: 0.8230
# Out-of-Sample Accuracy: 0.7991
#
#
# In-Sample Precision: 0.7125
# Out-of-Sample Precision: 0.6549
#
#
# In-Sample Recall: 0.5567
# Out-of-Sample Recall: 0.5274

# %% [markdown]
# **Step 15:** Compute the AUC numbers

# %%
from sklearn.metrics import roc_curve, auc

in_sample_preds = [x[0] for x in model.predict(X_train)]
out_sample_preds = [x[0] for x in model.predict(X_test)]

in_sample_fpr, in_sample_tpr, in_sample_thresholds = roc_curve(y_train, in_sample_preds)
out_sample_fpr, out_sample_tpr, out_sample_thresholds = roc_curve(y_test, out_sample_preds)

in_sample_roc_auc = auc(in_sample_fpr, in_sample_tpr)
out_sample_roc_auc = auc(out_sample_fpr, out_sample_tpr)

print('In-Sample AUC: %0.4f' % in_sample_roc_auc)
print('Out-Sample AUC: %0.4f' % out_sample_roc_auc)
# Out:
# In-Sample AUC: 0.8834
# Out-Sample AUC: 0.8223

# %% [markdown]
# **Step 16:** visualize this data in the ROC curve

# %%
plt.figure(figsize=(10,7))

plt.plot(
    out_sample_fpr, out_sample_tpr, color='darkorange', label='Out-Sample ROC curve (area = %0.4f)' % in_sample_roc_auc
)
plt.plot(
    in_sample_fpr, in_sample_tpr, color='navy', label='In-Sample ROC curve (area = %0.4f)' % out_sample_roc_auc
)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.grid()
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")

plt.show()
